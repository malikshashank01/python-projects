# %%
import pandas as pd #for data processing
import numpy as np # for numeric operations
import warnings

warnings.filterwarnings("ignore") # for ignorng the warnings if we get it during coding

# %%
# global variables

# %%
#script functions
def load_data(path):
    dataset = pd.read_csv(path)
    return dataset

# %%
#load_data("C:/Users/shashank malik/Downloads/Stores.csv") #used functions to load data
data = pd.read_csv("C:/Users/shashank malik/Downloads/Stores.csv")

# %%
data.head() # data read
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
data.info() #to get the data information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
#seems there are not a single value of null
data.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
data.shape # checking no of columns and rows
# Out:
# (896, 5)

# %%
# stastical approach
data.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %%
data.value_counts()
# Out:
# Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 1          1659        1961             530                   66490          1
# 2          1461        1752             210                   39820          1
# 591        1206        1437             1330                  54060          1
# 592        1847        2186             910                   75120          1
# 593        1009        1202             330                   41600          1
#                                                                             ..
# 303        1391        1648             720                   77070          1
# 304        1577        1892             560                   74730          1
# 305        1092        1314             600                   76530          1
# 306        1375        1681             440                   68900          1
# 896        1174        1429             1110                  54340          1
# Length: 896, dtype: int64

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS
#
# UNIVARIATE ANALYSIS
#
# -NUMERICAL
#
# -CATEGORICAL(not applicable in this data set

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
dummy = data['Store_Area'].value_counts()
dummy
# Out:
# 1439    5
# 1513    5
# 1458    5
# 1440    5
# 1539    5
#        ..
# 1509    1
# 1339    1
# 1590    1
# 2169    1
# 1387    1
# Name: Store_Area, Length: 583, dtype: int64

# %%
#univariate analysis
#store area
dummy = data['Store_Area'].value_counts()
sns.barplot(data = dummy,x=dummy.values,y=dummy.index)
plt.show()

# %%
sns.kdeplot(data = data , x='Store_Area' , color = 'blue')
sns.kdeplot(data = data , x='Daily_Customer_Count' , color = 'blue')
sns.kdeplot(data = data ,x = 'Items_Available', color = 'black')

plt.show()
plt.show()

# %%
#univariate analysis
#Items_Available
data.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
sns.kdeplot(data = data ,x = 'Items_Available', color = 'black')
plt.show()

# %%
#univariate analysis
#store sales
sns.kdeplot(data=data , x='Store_Sales' , color = 'red')

plt.show()

# %%
#graphical overview of data

sns.kdeplot(data = data , x='Store_Area' , color = 'blue')
sns.kdeplot(data = data , x='Daily_Customer_Count' , color = 'blue')
sns.kdeplot(data = data ,x = 'Items_Available', color = 'black')
sns.kdeplot(data=data , x='Store_Sales' , color = 'red')

plt.show()
plt.show()
plt.show()
plt.show()

# %% [markdown]
# # Hence sales are not increasing even if the items,daily customers and store area are very high

# %%
#univariate analysis
#store sales
sns.set_theme(style = 'whitegrid')
sns.boxplot(y = data['Store_Sales'])
# Out:
# <AxesSubplot:ylabel='Store_Sales'>

# %%
#univariate analysis
#daily customer count
sns.set_theme(style = 'whitegrid')
sns.boxplot(y = data['Daily_Customer_Count'])
# Out:
# <AxesSubplot:ylabel='Daily_Customer_Count'>

# %%
#bivariate analysis
#pair plot to see the coorelations
sns.pairplot(data)
plt.show()

# %%
#heatmaps to check the which variable is positively coorelated and negatively coorelatd 
corr = data.corr()
sns.heatmap(corr,vmin=-1,vmax=1,annot = True, linewidth = 4)
plt.show()

# %%
#bivariate analysis
#num vs num plot -

# %%
sns.scatterplot(x = 'Store_Sales',y = 'Items_Available',data = data)
plt.show()

# %%
sns.scatterplot(x = 'Store_Area',y = 'Items_Available',data = data)
plt.show()

# %%
sns.scatterplot(x = 'Daily_Customer_Count',y = 'Items_Available',data = data)
plt.show()

# %%
sns.scatterplot(x = 'Daily_Customer_Count',y = 'Store_Sales',data = data)
plt.show()

# %% [markdown]
# # EDA REPORT
#
# 1-sales and daily customers count are slightly coorelated, hence sales are only slightly affected with the arrivals of customers
#
# 2-items available and daily customers count are slightly coorelated, hence customers are not heavely affected with the availability of items. so must increase the number of products of different varieties to make the customers increase the sales.
#
# 3-store area and daily cutomers counts are heavely coorelated , so there is no need to increase or decrease the area of store.
#
# 4-sales and items available are minutely coorelated,hence availabilty of items are not affecting the sales so its highely recommended to bring and increace the variety of products to attract te customers and increase the sales.

# %% [markdown]
# # MODELLING

# %%
data.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %% [markdown]
# # Performing Simple Linear Regression
# Equation of linear regression
#
# 𝑦=𝑐+𝑚1𝑥1+𝑚2𝑥2+...+𝑚𝑛𝑥𝑛
#
# 𝑦  is the response
#
# 𝑐  is the intercept
#
# 𝑚1  is the coefficient for the first feature
#
# 𝑚𝑛  is the coefficient for the nth feature
#
# In our case:
#
# 𝑦=𝑐+𝑚1×𝑇𝑉
#
# The  𝑚  values are called the model coefficients or model parameters.

# %% [markdown]
# # Generic Steps in model building using statsmodels
#
#
# We first assign the feature variable, TV, in this case, to the variable X and the response variable, Sales, to the variable y.

# %%
x = data['Items_Available']
y = data['Store_Sales']

# %% [markdown]
# # Train-Test Split
#
# You now need to split our variable into training and testing sets. You'll perform this by importing train_test_split from the sklearn.model_selection library. It is usually a good practice to keep 70% of the data in your train dataset and the rest 30% in your test dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,test_size=0.3,random_state=100)

# %%
# Let's now take a look at the train dataset

x_train.head()
# Out:
# 85     1760
# 798    2420
# 161    1657
# 461    1940
# 517    1616
# Name: Items_Available, dtype: int64

# %%
y_train.head()
# Out:
# 85     51280
# 798    85670
# 161    45020
# 461    44240
# 517    62770
# Name: Store_Sales, dtype: int64

# %% [markdown]
# # Building a Linear Model
# You first need to import the statsmodel.api library using which you'll perform the linear regression.

# %%
import statsmodels.api as sm

# %% [markdown]
# #
# By default, the statsmodels library fits a line on the dataset which passes through the origin. But in order to have an intercept, you need to manually use the add_constant attribute of statsmodels. And once you've added the constant to your X_train dataset, you can go ahead and fit a regression line using the OLS (Ordinary Least Squares) attribute of statsmodels as shown below

# %%
# Add a constant to get an intercept
x_train_sm = sm.add_constant(x_train)

# Fit the resgression line using 'OLS' (Ordinary Least Squares regression) 

lr = sm.OLS(y_train, x_train_sm).fit()

# %%
# Print the parameters, i.e. the intercept and the slope of the regression line fitted
lr.params
# Out:
# const              48385.180243
# Items_Available        6.289538
# dtype: float64

# %%
# Performing a summary operation lists out all the different parameters of the regression line fitted
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Store_Sales   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     7.825
# Date:                Sat, 16 Jul 2022   Prob (F-statistic):            0.00531
# Time:                        17:36:28   Log-Likelihood:                -6996.8
# No. Observations:                 627   AIC:                         1.400e+04
# Df Residuals:                     625   BIC:                         1.401e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            4.839e+04   4055.670     11.930      0.000    4.04e+04    5.63e+04
# ...

# %% [markdown]
# #
# Looking at some key statistics from the summary
#
# The values we are concerned with are -
#
# The coefficients and significance (p-values)
#
# R-squared
#
# F statistic and its significance

# %% [markdown]
# # 1. The coefficient for Items available is 6.2895, with a very low p value

# %% [markdown]
# # 2 R-Squared is 0.012

# %% [markdown]
# # 3  F statistic has a very low p value (practically low)

# %% [markdown]
# ### Let's visualize how well the model fit the data.

# %% [markdown]
# ### 𝑆𝑎𝑙𝑒𝑠=4.839e+04 + 6.2895×Items available

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, 4.839e+04 + 6.2895*x_train, 'r')
plt.show()

# %% [markdown]
# #  Residual analysis
#
# ###To validate assumptions of the model, and hence the reliability for inference
#
# Distribution of the error terms
# We need to check if the error terms are also normally distributed (which is infact, one of the major assumptions of linear regression), let us plot the histogram of the error terms and see what it looks like.

# %%
y_train_pred = lr.predict(x_train_sm)
res = (y_train - y_train_pred)

# %%
fig = plt.figure()
sns.distplot(res, bins = 15)
fig.suptitle('Error Terms', fontsize = 15)                  # Plot heading 
plt.xlabel('y_train - y_train_pred', fontsize = 15)         # X-label
plt.show()

# %% [markdown]
# #
# The residuals are following the normally distributed with a mean 0. All good!

# %% [markdown]
# Looking for patterns in the residuals¶

# %%
plt.scatter(x_train,res)
plt.show()

# %% [markdown]
# ###
# We are confident that the model fit isn't by chance, and has decent predictive power. The normality of residual terms allows some inference on the coefficients.
#
# Although, the variance of residuals increasing with X indicates that there is significant variation that this model is unable to explain.
#
# As you can see, the regression line is a pretty good fit to the data

# %% [markdown]
# # Step 5: Predictions on the Test Set
#
# Now that you have fitted a regression line on your train dataset, it's time to make some predictions on the test data. For this, you first need to add a constant to the X_test data like you did for X_train and then you can simply go on and predict the y values corresponding to X_test using the predict attribute of the fitted regression line.

# %%
# Add a constant to x_test
x_test_sm = sm.add_constant(x_test)

# Predict the y values corresponding to x_test_sm
y_pred = lr.predict(x_test_sm)

# %%
y_pred.head()
# Out:
# 205    61901.398391
# 44     55894.889163
# 825    58637.127931
# 459    58876.130393
# 799    57869.804239
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ##### Looking at the RMSE

# %%
#Returns the mean squared error; we'll take a square root
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 17361.030116037084

# %% [markdown]
# #### Checking the R-squared on the test set

# %%
r_squared = r2_score(y_test, y_pred)
r_squared
# Out:
# 0.001670764672769609

# %% [markdown]
# ### Visualizing the fit on the test set

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, 4.839e+04 + 6.2895* x_test, 'r')
plt.show()

# %% [markdown]
# # Linear Regression using linear_model in sklearn
# Apart from statsmodels, there is another package namely sklearn that can be used to perform linear regression. We will use the linear_model library from sklearn to build the model. Since, we hae already performed a train-test split, we don't need to do it again.
#
# There's one small step that we need to add, though. When there's only a single feature, we need to add an additional column in order for the linear regression fit to be performed successfully.

# %%
from sklearn.model_selection import train_test_split
x_train_lm, x_test_lm, y_train_lm, y_test_lm = train_test_split(x, y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
x_train_lm.shape
# Out:
# (627,)

# %%
x_train_lm = x_train_lm.reshape(-1,1)
x_test_lm = x_test_lm.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24476/452111140.py in <module>
# ----> 1 x_train_lm = x_train_lm.reshape(-1,1)
#       2 x_test_lm = x_test_lm.reshape(-1,1)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
print(x_train_lm.shape)
print(y_train_lm.shape)
print(x_test_lm.shape)
print(y_test_lm.shape)
# Out:
# (627,)
# (627,)
# (269,)
# (269,)

# %%
from sklearn.linear_model import LinearRegression

# Representing LinearRegression as lr(Creating LinearRegression Object)
lm = LinearRegression()

# Fit the model using lr.fit()
lm.fit(x_train_lm, y_train_lm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24476/1856350399.py in <module>
#       5
#       6 # Fit the model using lr.fit()
# ----> 7 lm.fit(x_train_lm, y_train_lm)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...
